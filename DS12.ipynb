# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Read the CSV file into a DataFrame
df = pd.read_csv('D:/Data science ass/12/EDA2/adult_with_headers.csv')

# Display the first 5 rows
print(df.head().to_markdown(index=False, numalign="left", stralign="left"))

# Print the column names and their data types
print(df.info())

# Print descriptive statistics for numerical columns
print("Descriptive statistics for numerical columns: \n")
print(df.describe(include=[int, float]).to_markdown(numalign="left", stralign="left"))

# Print descriptive statistics for non-numerical columns
print("\nDescriptive statistics for non-numerical columns: \n")
print(df.describe(include=[object]).to_markdown(numalign="left", stralign="left"))

# Check for missing values
print("\nMissing values: \n")
print(df.isnull().sum().to_markdown(numalign="left", stralign="left"))
# Out:
# | age   | workclass        | fnlwgt   | education   | education_num   | marital_status     | occupation        | relationship   | race   | sex    | capital_gain   | capital_loss   | hours_per_week   | native_country   | income   |
# |:------|:-----------------|:---------|:------------|:----------------|:-------------------|:------------------|:---------------|:-------|:-------|:---------------|:---------------|:-----------------|:-----------------|:---------|
# | 39    | State-gov        | 77516    | Bachelors   | 13              | Never-married      | Adm-clerical      | Not-in-family  | White  | Male   | 2174           | 0              | 40               | United-States    | <=50K    |
# | 50    | Self-emp-not-inc | 83311    | Bachelors   | 13              | Married-civ-spouse | Exec-managerial   | Husband        | White  | Male   | 0              | 0              | 13               | United-States    | <=50K    |
# | 38    | Private          | 215646   | HS-grad     | 9               | Divorced           | Handlers-cleaners | Not-in-family  | White  | Male   | 0              | 0              | 40               | United-States    | <=50K    |
# | 53    | Private          | 234721   | 11th        | 7               | Married-civ-spouse | Handlers-cleaners | Husband        | Black  | Male   | 0              | 0              | 40               | United-States    | <=50K    |
# | 28    | Private          | 338409   | Bachelors   | 13              | Married-civ-spouse | Prof-specialty    | Wife           | Black  | Female | 0              | 0              | 40               | Cuba             | <=50K    |
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None
# Descriptive statistics for numerical columns:
#
# |       | age     | fnlwgt     | education_num   | capital_gain   | capital_loss   | hours_per_week   |
# |:------|:--------|:-----------|:----------------|:---------------|:---------------|:-----------------|
# | count | 32561   | 32561      | 32561           | 32561          | 32561          | 32561            |
# | mean  | 38.5816 | 189778     | 10.0807         | 1077.65        | 87.3038        | 40.4375          |
# | std   | 13.6404 | 105550     | 2.57272         | 7385.29        | 402.96         | 12.3474          |
# | min   | 17      | 12285      | 1               | 0              | 0              | 1                |
# | 25%   | 28      | 117827     | 9               | 0              | 0              | 40               |
# | 50%   | 37      | 178356     | 10              | 0              | 0              | 40               |
# | 75%   | 48      | 237051     | 12              | 0              | 0              | 45               |
# | max   | 90      | 1.4847e+06 | 16              | 99999          | 4356           | 99               |
#
# Descriptive statistics for non-numerical columns:
#
# |        | workclass   | education   | marital_status     | occupation     | relationship   | race   | sex   | native_country   | income   |
# |:-------|:------------|:------------|:-------------------|:---------------|:---------------|:-------|:------|:-----------------|:---------|
# | count  | 32561       | 32561       | 32561              | 32561          | 32561          | 32561  | 32561 | 32561            | 32561    |
# | unique | 9           | 16          | 7                  | 15             | 6              | 5      | 2     | 42               | 2        |
# | top    | Private     | HS-grad     | Married-civ-spouse | Prof-specialty | Husband        | White  | Male  | United-States    | <=50K    |
# | freq   | 22696       | 10501       | 14976              | 4140           | 13193          | 27816  | 21790 | 29170            | 24720    |
#
# Missing values:
#
# |                | 0   |
# |:---------------|:----|
# | age            | 0   |
# | workclass      | 0   |
# | fnlwgt         | 0   |
# | education      | 0   |
# | education_num  | 0   |
# | marital_status | 0   |
# | occupation     | 0   |
# | relationship   | 0   |
# | race           | 0   |
# | sex            | 0   |
# | capital_gain   | 0   |
# | capital_loss   | 0   |
# | hours_per_week | 0   |
# | native_country | 0   |
# | income         | 0   |

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Identify numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Initialize scalers
standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

# Apply standard scaling
df_scaled_standard = df.copy()
df_scaled_standard[numerical_cols] = standard_scaler.fit_transform(df_scaled_standard[numerical_cols])

# Apply min-max scaling
df_scaled_minmax = df.copy()
df_scaled_minmax[numerical_cols] = minmax_scaler.fit_transform(df_scaled_minmax[numerical_cols])

# Display the first 5 rows of the scaled DataFrames
print("\nFirst 5 rows after standard scaling: \n")
print(df_scaled_standard.head().to_markdown(index=False, numalign="left", stralign="left"))

print("\nFirst 5 rows after min-max scaling: \n")
print(df_scaled_minmax.head().to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# First 5 rows after standard scaling:
#
# | age       | workclass        | fnlwgt   | education   | education_num   | marital_status     | occupation        | relationship   | race   | sex    | capital_gain   | capital_loss   | hours_per_week   | native_country   | income   |
# |:----------|:-----------------|:---------|:------------|:----------------|:-------------------|:------------------|:---------------|:-------|:-------|:---------------|:---------------|:-----------------|:-----------------|:---------|
# | 0.0306706 | State-gov        | -1.06361 | Bachelors   | 1.13474         | Never-married      | Adm-clerical      | Not-in-family  | White  | Male   | 0.148453       | -0.21666       | -0.0354294       | United-States    | <=50K    |
# | 0.837109  | Self-emp-not-inc | -1.00871 | Bachelors   | 1.13474         | Married-civ-spouse | Exec-managerial   | Husband        | White  | Male   | -0.14592       | -0.21666       | -2.22215         | United-States    | <=50K    |
# | -0.042642 | Private          | 0.245079 | HS-grad     | -0.42006        | Divorced           | Handlers-cleaners | Not-in-family  | White  | Male   | -0.14592       | -0.21666       | -0.0354294       | United-States    | <=50K    |
# | 1.05705   | Private          | 0.425801 | 11th        | -1.19746        | Married-civ-spouse | Handlers-cleaners | Husband        | Black  | Male   | -0.14592       | -0.21666       | -0.0354294       | United-States    | <=50K    |
# | -0.775768 | Private          | 1.40818  | Bachelors   | 1.13474         | Married-civ-spouse | Prof-specialty    | Wife           | Black  | Female | -0.14592       | -0.21666       | -0.0354294       | Cuba             | <=50K    |
#
# First 5 rows after min-max scaling:
#
# | age      | workclass        | fnlwgt    | education   | education_num   | marital_status     | occupation        | relationship   | race   | sex    | capital_gain   | capital_loss   | hours_per_week   | native_country   | income   |
# |:---------|:-----------------|:----------|:------------|:----------------|:-------------------|:------------------|:---------------|:-------|:-------|:---------------|:---------------|:-----------------|:-----------------|:---------|
# | 0.30137  | State-gov        | 0.0443019 | Bachelors   | 0.8             | Never-married      | Adm-clerical      | Not-in-family  | White  | Male   | 0.0217402      | 0              | 0.397959         | United-States    | <=50K    |
# | 0.452055 | Self-emp-not-inc | 0.0482376 | Bachelors   | 0.8             | Married-civ-spouse | Exec-managerial   | Husband        | White  | Male   | 0              | 0              | 0.122449         | United-States    | <=50K    |
# | 0.287671 | Private          | 0.138113  | HS-grad     | 0.533333        | Divorced           | Handlers-cleaners | Not-in-family  | White  | Male   | 0              | 0              | 0.397959         | United-States    | <=50K    |
# | 0.493151 | Private          | 0.151068  | 11th        | 0.4             | Married-civ-spouse | Handlers-cleaners | Husband        | Black  | Male   | 0              | 0              | 0.397959         | United-States    | <=50K    |
# | 0.150685 | Private          | 0.221488  | Bachelors   | 0.8             | Married-civ-spouse | Prof-specialty    | Wife           | Black  | Female | 0              | 0              | 0.397959         | Cuba             | <=50K    |

# %% [markdown]
# The choice between these techniques depends on the specific characteristics of your data and the requirements of your machine learning algorithm. If your data is normally distributed or your algorithm is sensitive to feature scales, StandardScaler is often a good choice. If you need to control the range of your features or want to reduce the impact of outliers, MinMaxScaler might be more suitable. It's often a good practice to experiment with both techniques and evaluate their impact on your model's performance.

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Get all categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# Lists to store low and high cardinality columns
low_cardinality_cols = []
high_cardinality_cols = []

# Categorize columns based on cardinality
for col in categorical_cols:
    if df[col].nunique() < 5:
        low_cardinality_cols.append(col)
    else:
        high_cardinality_cols.append(col)

# One-hot encode low cardinality columns
encoder_ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
encoded_cols = encoder_ohe.fit_transform(df[low_cardinality_cols])
encoded_col_names = encoder_ohe.get_feature_names_out(low_cardinality_cols)
df_encoded = pd.DataFrame(encoded_cols, columns=encoded_col_names)

# Label encode high cardinality columns
encoder_le = LabelEncoder()
for col in high_cardinality_cols:
    df_encoded[col] = encoder_le.fit_transform(df[col])

# Add numerical columns to the encoded DataFrame
df_encoded[numerical_cols] = df[numerical_cols]

# Display the first 5 rows
print(df_encoded.head().to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# | sex_ Female   | sex_ Male   | income_ <=50K   | income_ >50K   | workclass   | education   | marital_status   | occupation   | relationship   | race   | native_country   | age   | fnlwgt   | education_num   | capital_gain   | capital_loss   | hours_per_week   |
# |:--------------|:------------|:----------------|:---------------|:------------|:------------|:-----------------|:-------------|:---------------|:-------|:-----------------|:------|:---------|:----------------|:---------------|:---------------|:-----------------|
# | 0             | 1           | 1               | 0              | 7           | 9           | 4                | 1            | 1              | 4      | 39               | 39    | 77516    | 13              | 2174           | 0              | 40               |
# | 0             | 1           | 1               | 0              | 6           | 9           | 2                | 4            | 0              | 4      | 39               | 50    | 83311    | 13              | 0              | 0              | 13               |
# | 0             | 1           | 1               | 0              | 4           | 11          | 0                | 6            | 1              | 4      | 39               | 38    | 215646   | 9               | 0              | 0              | 40               |
# | 0             | 1           | 1               | 0              | 4           | 1           | 2                | 6            | 0              | 2      | 39               | 53    | 234721   | 7               | 0              | 0              | 40               |
# | 1             | 0           | 1               | 0              | 4           | 9           | 2                | 10           | 5              | 2      | 5                | 28    | 338409   | 13              | 0              | 0              | 40               |

# %% [markdown]
# One-Hot Encoding: This technique creates a new binary column for each unique value in a categorical feature. It avoids imposing any ordinal relationship between categories, which is crucial for algorithms that don't assume such relationships (e.g., decision trees, random forests). However, it can significantly increase the dimensionality of the dataset, especially for features with many unique values
#
# Label Encoding: This technique assigns a unique numerical label to each category in a feature. It's simple and efficient, especially for features with many categories. However, it can introduce an artificial ordinal relationship between categories, which might mislead algorithms that interpret numerical values as having an order

# %%
import numpy as np

# Create new feature 'total_income'
df_encoded['total_income'] = df_encoded['capital_gain'] + df_encoded['capital_loss']

# Create new feature 'financial_dependency'
df_encoded['financial_dependency'] = np.where(df_encoded['relationship'].isin(['Husband', 'Wife']), 0, 1)

# Check skewness of numerical columns
skewness = df_encoded.select_dtypes(include=np.number).skew()
skewed_cols = skewness[(skewness > 1) | (skewness < -1)].index.tolist()
print(f"Skewed columns: {skewed_cols}")

# Apply log transformation to skewed columns
for col in skewed_cols:
    df_encoded[col + '_log'] = np.log1p(df_encoded[col])  # Use log1p to handle 0 values

# Display the first 5 rows
print(df_encoded.head().to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# Skewed columns: ['income_ <=50K', 'income_ >50K', 'race', 'native_country', 'fnlwgt', 'capital_gain', 'capital_loss', 'total_income']
# | sex_ Female   | sex_ Male   | income_ <=50K   | income_ >50K   | workclass   | education   | marital_status   | occupation   | relationship   | race   | native_country   | age   | fnlwgt   | education_num   | capital_gain   | capital_loss   | hours_per_week   | total_income   | financial_dependency   | income_ <=50K_log   | income_ >50K_log   | race_log   | native_country_log   | fnlwgt_log   | capital_gain_log   | capital_loss_log   | total_income_log   |
# |:--------------|:------------|:----------------|:---------------|:------------|:------------|:-----------------|:-------------|:---------------|:-------|:-----------------|:------|:---------|:----------------|:---------------|:---------------|:-----------------|:---------------|:-----------------------|:--------------------|:-------------------|:-----------|:---------------------|:-------------|:-------------------|:-------------------|:-------------------|
# | 0             | 1           | 1               | 0              | 7           | 9           | 4                | 1            | 1              | 4      | 39               | 39    | 77516    | 13              | 2174           | 0              | 40               | 2174           | 1                      | 0.693147            | 0                  | 1.60944    | 3.68888              | 11.2583      | 7.68478            | 0                  | 7.68478            |
# | 0             | 1           | 1               | 0              | 6           | 9           | 2                | 4            | 0              | 4      | 39               | 50    | 83311    | 13              | 0              | 0              | 13               | 0              | 1                      | 0.693147            | 0                  | 1.60944    | 3.68888              | 11.3303      | 0                  | 0                  | 0                  |
# | 0             | 1           | 1               | 0              | 4           | 11          | 0                | 6            | 1              | 4      | 39               | 38    | 215646   | 9               | 0              | 0              | 40               | 0              | 1                      | 0.693147            | 0                  | 1.60944    | 3.68888              | 12.2814      | 0                  | 0                  | 0                  |
# | 0             | 1           | 1               | 0              | 4           | 1           | 2                | 6            | 0              | 2      | 39               | 53    | 234721   | 7               | 0              | 0              | 40               | 0              | 1                      | 0.693147            | 0                  | 1.09861    | 3.68888              | 12.3662      | 0                  | 0                  | 0                  |
# | 1             | 0           | 1               | 0              | 4           | 9           | 2                | 10           | 5              | 2      | 5                | 28    | 338409   | 13              | 0              | 0              | 40               | 0              | 1                      | 0.693147            | 0                  | 1.09861    | 1.79176              | 12.732       | 0                  | 0                  | 0                  |

# %% [markdown]
# Two new features have been created:
#
# 'total_income': This feature combines 'capital_gain' and 'capital_loss' to provide a more comprehensive view of an individual's financial situation. It might be more informative than considering these gains and losses separately, as it reflects the net financial impact.
#
# 'financial_dependency': This feature indicates whether an individual is likely to be financially dependent on their spouse, based on their relationship status. It could be relevant for predicting income, as financial dependents might have different income patterns compared to those who are financially independ
#
# Additionally, log transformation has been applied to the following skewed features:
#
# 'fnlwgt'
# 'capital_gain'
# 'capital_loss'
# 'total_income'
# 'income_ <=50K'
# 'income_ >50K'
# 'race'
# 'native_country'
# These features exhibited high skewness, which can negatively impact the performance of many machine learning algorithms. Log transformation compresses the range of these features, reducing the influence of extreme values and making their distributions more symmetrical. This can improve the model's ability to learn patterns and make accurate p.redictionsent.

# %%
from sklearn.ensemble import IsolationForest

# Copy the DataFrame to avoid modifying the original
df_no_outliers = df_encoded.copy()

# Initialize and fit Isolation Forest
clf = IsolationForest(contamination=0.05, random_state=42)  # Adjust contamination as needed
clf.fit(df_no_outliers[numerical_cols + ['total_income_log']])  # Include the log-transformed feature

# Predict outliers
df_no_outliers['outlier'] = clf.predict(df_no_outliers[numerical_cols + ['total_income_log']])

# Remove outliers
print(f"Shape before removing outliers: {df_no_outliers.shape}")
df_no_outliers = df_no_outliers[df_no_outliers['outlier'] != -1]
print(f"Shape after removing outliers: {df_no_outliers.shape}")

# Calculate PPS matrix
from ppscore import matrix

pps_matrix = matrix(df_no_outliers)

# Calculate correlation matrix
corr_matrix = df_no_outliers.corr()

# Print the matrices
print("\nPPS Matrix: \n")
print(pps_matrix.round(2).to_markdown(numalign="left", stralign="left"))

print("\nCorrelation Matrix: \n")
print(corr_matrix.round(2).to_markdown(numalign="left", stralign="left"))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Shape before removing outliers: (32561, 28)
# Shape after removing outliers: (30933, 28)
#
# PPS Matrix:
#
# |     | x                    | y                    | ppscore   | case               | is_valid_score   | metric              | baseline_score   | model_score   | model                   |
# |:----|:---------------------|:---------------------|:----------|:-------------------|:-----------------|:--------------------|:-----------------|:--------------|:------------------------|
# | 0   | sex_ Female          | sex_ Female          | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 1   | sex_ Female          | sex_ Male            | 1         | regression         | True             | mean absolute error | 0.34             | 0             | DecisionTreeRegressor() |
# | 2   | sex_ Female          | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.32          | DecisionTreeRegressor() |
# | 3   | sex_ Female          | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.32          | DecisionTreeRegressor() |
# | 4   | sex_ Female          | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.82          | DecisionTreeRegressor() |
# | 5   | sex_ Female          | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.86          | DecisionTreeRegressor() |
# | 6   | sex_ Female          | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.26          | DecisionTreeRegressor() |
# | 7   | sex_ Female          | occupation           | 0         | regression         | True             | mean absolute error | 3.72             | 3.73          | DecisionTreeRegressor() |
# | 8   | sex_ Female          | relationship         | 0.13      | regression         | True             | mean absolute error | 1.27             | 1.1           | DecisionTreeRegressor() |
# | 9   | sex_ Female          | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.58          | DecisionTreeRegressor() |
# | 10  | sex_ Female          | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.94          | DecisionTreeRegressor() |
# | 11  | sex_ Female          | age                  | 0         | regression         | True             | mean absolute error | 11.05            | 11.11         | DecisionTreeRegressor() |
# | 12  | sex_ Female          | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76280.4       | DecisionTreeRegressor() |
# | 13  | sex_ Female          | education_num        | 0         | regression         | True             | mean absolute error | 1.81             | 1.82          | DecisionTreeRegressor() |
# | 14  | sex_ Female          | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 769.84        | DecisionTreeRegressor() |
# | 15  | sex_ Female          | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.72         | DecisionTreeRegressor() |
# | 16  | sex_ Female          | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.79          | DecisionTreeRegressor() |
# | 17  | sex_ Female          | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 823.17        | DecisionTreeRegressor() |
# | 18  | sex_ Female          | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 19  | sex_ Female          | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.22          | DecisionTreeRegressor() |
# | 20  | sex_ Female          | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.22          | DecisionTreeRegressor() |
# | 21  | sex_ Female          | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.17          | DecisionTreeRegressor() |
# | 22  | sex_ Female          | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.23          | DecisionTreeRegressor() |
# | 23  | sex_ Female          | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 24  | sex_ Female          | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.07          | DecisionTreeRegressor() |
# | 25  | sex_ Female          | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 26  | sex_ Female          | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.37          | DecisionTreeRegressor() |
# | 27  | sex_ Female          | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 28  | sex_ Male            | sex_ Female          | 1         | regression         | True             | mean absolute error | 0.34             | 0             | DecisionTreeRegressor() |
# | 29  | sex_ Male            | sex_ Male            | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 30  | sex_ Male            | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.32          | DecisionTreeRegressor() |
# | 31  | sex_ Male            | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.32          | DecisionTreeRegressor() |
# | 32  | sex_ Male            | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.82          | DecisionTreeRegressor() |
# | 33  | sex_ Male            | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.86          | DecisionTreeRegressor() |
# | 34  | sex_ Male            | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.26          | DecisionTreeRegressor() |
# | 35  | sex_ Male            | occupation           | 0         | regression         | True             | mean absolute error | 3.72             | 3.73          | DecisionTreeRegressor() |
# | 36  | sex_ Male            | relationship         | 0.13      | regression         | True             | mean absolute error | 1.27             | 1.1           | DecisionTreeRegressor() |
# | 37  | sex_ Male            | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.58          | DecisionTreeRegressor() |
# | 38  | sex_ Male            | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.94          | DecisionTreeRegressor() |
# | 39  | sex_ Male            | age                  | 0         | regression         | True             | mean absolute error | 11.05            | 11.11         | DecisionTreeRegressor() |
# | 40  | sex_ Male            | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76280.4       | DecisionTreeRegressor() |
# | 41  | sex_ Male            | education_num        | 0         | regression         | True             | mean absolute error | 1.81             | 1.82          | DecisionTreeRegressor() |
# | 42  | sex_ Male            | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 769.84        | DecisionTreeRegressor() |
# | 43  | sex_ Male            | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.72         | DecisionTreeRegressor() |
# | 44  | sex_ Male            | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.79          | DecisionTreeRegressor() |
# | 45  | sex_ Male            | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 823.17        | DecisionTreeRegressor() |
# | 46  | sex_ Male            | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 47  | sex_ Male            | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.22          | DecisionTreeRegressor() |
# | 48  | sex_ Male            | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.22          | DecisionTreeRegressor() |
# | 49  | sex_ Male            | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.17          | DecisionTreeRegressor() |
# | 50  | sex_ Male            | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.23          | DecisionTreeRegressor() |
# | 51  | sex_ Male            | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 52  | sex_ Male            | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.07          | DecisionTreeRegressor() |
# | 53  | sex_ Male            | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 54  | sex_ Male            | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.37          | DecisionTreeRegressor() |
# | 55  | sex_ Male            | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 56  | income_ <=50K        | sex_ Female          | 0         | regression         | True             | mean absolute error | 0.34             | 0.43          | DecisionTreeRegressor() |
# | 57  | income_ <=50K        | sex_ Male            | 0         | regression         | True             | mean absolute error | 0.34             | 0.43          | DecisionTreeRegressor() |
# | 58  | income_ <=50K        | income_ <=50K        | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 59  | income_ <=50K        | income_ >50K         | 1         | regression         | True             | mean absolute error | 0.22             | 0             | DecisionTreeRegressor() |
# | 60  | income_ <=50K        | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.82          | DecisionTreeRegressor() |
# | 61  | income_ <=50K        | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.87          | DecisionTreeRegressor() |
# | 62  | income_ <=50K        | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.2           | DecisionTreeRegressor() |
# | 63  | income_ <=50K        | occupation           | 0         | regression         | True             | mean absolute error | 3.72             | 3.72          | DecisionTreeRegressor() |
# | 64  | income_ <=50K        | relationship         | 0         | regression         | True             | mean absolute error | 1.27             | 1.34          | DecisionTreeRegressor() |
# | 65  | income_ <=50K        | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.59          | DecisionTreeRegressor() |
# | 66  | income_ <=50K        | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.94          | DecisionTreeRegressor() |
# | 67  | income_ <=50K        | age                  | 0.03      | regression         | True             | mean absolute error | 11.05            | 10.77         | DecisionTreeRegressor() |
# | 68  | income_ <=50K        | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76309.2       | DecisionTreeRegressor() |
# | 69  | income_ <=50K        | education_num        | 0.02      | regression         | True             | mean absolute error | 1.81             | 1.77          | DecisionTreeRegressor() |
# | 70  | income_ <=50K        | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 709.7         | DecisionTreeRegressor() |
# | 71  | income_ <=50K        | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.46         | DecisionTreeRegressor() |
# | 72  | income_ <=50K        | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.43          | DecisionTreeRegressor() |
# | 73  | income_ <=50K        | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 753.7         | DecisionTreeRegressor() |
# | 74  | income_ <=50K        | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 75  | income_ <=50K        | income_ <=50K_log    | 1         | regression         | True             | mean absolute error | 0.15             | 0             | DecisionTreeRegressor() |
# | 76  | income_ <=50K        | income_ >50K_log     | 1         | regression         | True             | mean absolute error | 0.15             | 0             | DecisionTreeRegressor() |
# | 77  | income_ <=50K        | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.17          | DecisionTreeRegressor() |
# | 78  | income_ <=50K        | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.23          | DecisionTreeRegressor() |
# | 79  | income_ <=50K        | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 80  | income_ <=50K        | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.02          | DecisionTreeRegressor() |
# | 81  | income_ <=50K        | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 82  | income_ <=50K        | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.3           | DecisionTreeRegressor() |
# | 83  | income_ <=50K        | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 84  | income_ >50K         | sex_ Female          | 0         | regression         | True             | mean absolute error | 0.34             | 0.43          | DecisionTreeRegressor() |
# | 85  | income_ >50K         | sex_ Male            | 0         | regression         | True             | mean absolute error | 0.34             | 0.43          | DecisionTreeRegressor() |
# | 86  | income_ >50K         | income_ <=50K        | 1         | regression         | True             | mean absolute error | 0.22             | 0             | DecisionTreeRegressor() |
# | 87  | income_ >50K         | income_ >50K         | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 88  | income_ >50K         | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.82          | DecisionTreeRegressor() |
# | 89  | income_ >50K         | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.87          | DecisionTreeRegressor() |
# | 90  | income_ >50K         | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.2           | DecisionTreeRegressor() |
# | 91  | income_ >50K         | occupation           | 0         | regression         | True             | mean absolute error | 3.72             | 3.72          | DecisionTreeRegressor() |
# | 92  | income_ >50K         | relationship         | 0         | regression         | True             | mean absolute error | 1.27             | 1.34          | DecisionTreeRegressor() |
# | 93  | income_ >50K         | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.59          | DecisionTreeRegressor() |
# | 94  | income_ >50K         | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.94          | DecisionTreeRegressor() |
# | 95  | income_ >50K         | age                  | 0.03      | regression         | True             | mean absolute error | 11.05            | 10.77         | DecisionTreeRegressor() |
# | 96  | income_ >50K         | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76309.2       | DecisionTreeRegressor() |
# | 97  | income_ >50K         | education_num        | 0.02      | regression         | True             | mean absolute error | 1.81             | 1.77          | DecisionTreeRegressor() |
# | 98  | income_ >50K         | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 709.7         | DecisionTreeRegressor() |
# | 99  | income_ >50K         | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.46         | DecisionTreeRegressor() |
# | 100 | income_ >50K         | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.43          | DecisionTreeRegressor() |
# | 101 | income_ >50K         | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 753.7         | DecisionTreeRegressor() |
# | 102 | income_ >50K         | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 103 | income_ >50K         | income_ <=50K_log    | 1         | regression         | True             | mean absolute error | 0.15             | 0             | DecisionTreeRegressor() |
# | 104 | income_ >50K         | income_ >50K_log     | 1         | regression         | True             | mean absolute error | 0.15             | 0             | DecisionTreeRegressor() |
# | 105 | income_ >50K         | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.17          | DecisionTreeRegressor() |
# | 106 | income_ >50K         | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.23          | DecisionTreeRegressor() |
# | 107 | income_ >50K         | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 108 | income_ >50K         | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.02          | DecisionTreeRegressor() |
# | 109 | income_ >50K         | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 110 | income_ >50K         | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.3           | DecisionTreeRegressor() |
# | 111 | income_ >50K         | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 112 | workclass            | sex_ Female          | 0         | regression         | True             | mean absolute error | 0.34             | 0.44          | DecisionTreeRegressor() |
# | 113 | workclass            | sex_ Male            | 0         | regression         | True             | mean absolute error | 0.34             | 0.44          | DecisionTreeRegressor() |
# | 114 | workclass            | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.33          | DecisionTreeRegressor() |
# | 115 | workclass            | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.33          | DecisionTreeRegressor() |
# | 116 | workclass            | workclass            | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 117 | workclass            | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.87          | DecisionTreeRegressor() |
# | 118 | workclass            | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.27          | DecisionTreeRegressor() |
# | 119 | workclass            | occupation           | 0.11      | regression         | True             | mean absolute error | 3.72             | 3.31          | DecisionTreeRegressor() |
# | 120 | workclass            | relationship         | 0         | regression         | True             | mean absolute error | 1.27             | 1.38          | DecisionTreeRegressor() |
# | 121 | workclass            | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.59          | DecisionTreeRegressor() |
# | 122 | workclass            | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.94          | DecisionTreeRegressor() |
# | 123 | workclass            | age                  | 0.01      | regression         | True             | mean absolute error | 11.05            | 10.9          | DecisionTreeRegressor() |
# | 124 | workclass            | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76374.7       | DecisionTreeRegressor() |
# | 125 | workclass            | education_num        | 0         | regression         | True             | mean absolute error | 1.81             | 1.83          | DecisionTreeRegressor() |
# | 126 | workclass            | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 773.87        | DecisionTreeRegressor() |
# | 127 | workclass            | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.62         | DecisionTreeRegressor() |
# | 128 | workclass            | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.11          | DecisionTreeRegressor() |
# | 129 | workclass            | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 827.47        | DecisionTreeRegressor() |
# | 130 | workclass            | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 131 | workclass            | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.23          | DecisionTreeRegressor() |
# | 132 | workclass            | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.23          | DecisionTreeRegressor() |
# | 133 | workclass            | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.17          | DecisionTreeRegressor() |
# | 134 | workclass            | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.23          | DecisionTreeRegressor() |
# | 135 | workclass            | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 136 | workclass            | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.08          | DecisionTreeRegressor() |
# | 137 | workclass            | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 138 | workclass            | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.37          | DecisionTreeRegressor() |
# | 139 | workclass            | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 140 | education            | sex_ Female          | 0         | regression         | True             | mean absolute error | 0.34             | 0.45          | DecisionTreeRegressor() |
# | 141 | education            | sex_ Male            | 0         | regression         | True             | mean absolute error | 0.34             | 0.45          | DecisionTreeRegressor() |
# | 142 | education            | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.3           | DecisionTreeRegressor() |
# | 143 | education            | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.3           | DecisionTreeRegressor() |
# | 144 | education            | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.84          | DecisionTreeRegressor() |
# | 145 | education            | education            | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 146 | education            | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.29          | DecisionTreeRegressor() |
# | 147 | education            | occupation           | 0.02      | regression         | True             | mean absolute error | 3.72             | 3.66          | DecisionTreeRegressor() |
# | 148 | education            | relationship         | 0         | regression         | True             | mean absolute error | 1.27             | 1.38          | DecisionTreeRegressor() |
# | 149 | education            | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.59          | DecisionTreeRegressor() |
# | 150 | education            | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.71          | DecisionTreeRegressor() |
# | 151 | education            | age                  | 0.01      | regression         | True             | mean absolute error | 11.05            | 10.89         | DecisionTreeRegressor() |
# | 152 | education            | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76338.6       | DecisionTreeRegressor() |
# | 153 | education            | education_num        | 1         | regression         | True             | mean absolute error | 1.81             | 0             | DecisionTreeRegressor() |
# | 154 | education            | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 765.61        | DecisionTreeRegressor() |
# | 155 | education            | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.54         | DecisionTreeRegressor() |
# | 156 | education            | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.43          | DecisionTreeRegressor() |
# | 157 | education            | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 817.97        | DecisionTreeRegressor() |
# | 158 | education            | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 159 | education            | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.21          | DecisionTreeRegressor() |
# | 160 | education            | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.21          | DecisionTreeRegressor() |
# | 161 | education            | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.17          | DecisionTreeRegressor() |
# | 162 | education            | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.22          | DecisionTreeRegressor() |
# | 163 | education            | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 164 | education            | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.07          | DecisionTreeRegressor() |
# | 165 | education            | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 166 | education            | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.37          | DecisionTreeRegressor() |
# | 167 | education            | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 168 | marital_status       | sex_ Female          | 0         | regression         | True             | mean absolute error | 0.34             | 0.36          | DecisionTreeRegressor() |
# | 169 | marital_status       | sex_ Male            | 0         | regression         | True             | mean absolute error | 0.34             | 0.36          | DecisionTreeRegressor() |
# | 170 | marital_status       | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.28          | DecisionTreeRegressor() |
# | 171 | marital_status       | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.28          | DecisionTreeRegressor() |
# | 172 | marital_status       | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.82          | DecisionTreeRegressor() |
# | 173 | marital_status       | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.85          | DecisionTreeRegressor() |
# | 174 | marital_status       | marital_status       | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 175 | marital_status       | occupation           | 0         | regression         | True             | mean absolute error | 3.72             | 3.73          | DecisionTreeRegressor() |
# | 176 | marital_status       | relationship         | 0.14      | regression         | True             | mean absolute error | 1.27             | 1.09          | DecisionTreeRegressor() |
# | 177 | marital_status       | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.58          | DecisionTreeRegressor() |
# | 178 | marital_status       | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.91          | DecisionTreeRegressor() |
# | 179 | marital_status       | age                  | 0.21      | regression         | True             | mean absolute error | 11.05            | 8.74          | DecisionTreeRegressor() |
# | 180 | marital_status       | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76288.4       | DecisionTreeRegressor() |
# | 181 | marital_status       | education_num        | 0         | regression         | True             | mean absolute error | 1.81             | 1.82          | DecisionTreeRegressor() |
# | 182 | marital_status       | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 757.88        | DecisionTreeRegressor() |
# | 183 | marital_status       | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.39         | DecisionTreeRegressor() |
# | 184 | marital_status       | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.84          | DecisionTreeRegressor() |
# | 185 | marital_status       | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 806.16        | DecisionTreeRegressor() |
# | 186 | marital_status       | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 187 | marital_status       | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.19          | DecisionTreeRegressor() |
# | 188 | marital_status       | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.19          | DecisionTreeRegressor() |
# | 189 | marital_status       | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.16          | DecisionTreeRegressor() |
# | 190 | marital_status       | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.22          | DecisionTreeRegressor() |
# | 191 | marital_status       | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 192 | marital_status       | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.06          | DecisionTreeRegressor() |
# | 193 | marital_status       | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 194 | marital_status       | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.35          | DecisionTreeRegressor() |
# | 195 | marital_status       | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 196 | occupation           | sex_ Female          | 0         | regression         | True             | mean absolute error | 0.34             | 0.36          | DecisionTreeRegressor() |
# | 197 | occupation           | sex_ Male            | 0         | regression         | True             | mean absolute error | 0.34             | 0.36          | DecisionTreeRegressor() |
# | 198 | occupation           | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.3           | DecisionTreeRegressor() |
# | 199 | occupation           | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.3           | DecisionTreeRegressor() |
# | 200 | occupation           | workclass            | 0.19      | regression         | True             | mean absolute error | 0.73             | 0.59          | DecisionTreeRegressor() |
# | 201 | occupation           | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.9           | DecisionTreeRegressor() |
# | 202 | occupation           | marital_status       | 0         | regression         | True             | mean absolute error | 1.2              | 1.23          | DecisionTreeRegressor() |
# | 203 | occupation           | occupation           | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 204 | occupation           | relationship         | 0         | regression         | True             | mean absolute error | 1.27             | 1.3           | DecisionTreeRegressor() |
# | 205 | occupation           | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.58          | DecisionTreeRegressor() |
# | 206 | occupation           | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.9           | DecisionTreeRegressor() |
# | 207 | occupation           | age                  | 0.01      | regression         | True             | mean absolute error | 11.05            | 10.97         | DecisionTreeRegressor() |
# | 208 | occupation           | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76269.9       | DecisionTreeRegressor() |
# | 209 | occupation           | education_num        | 0.15      | regression         | True             | mean absolute error | 1.81             | 1.54          | DecisionTreeRegressor() |
# | 210 | occupation           | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 767.87        | DecisionTreeRegressor() |
# | 211 | occupation           | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.52         | DecisionTreeRegressor() |
# | 212 | occupation           | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.59          | DecisionTreeRegressor() |
# | 213 | occupation           | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 819.15        | DecisionTreeRegressor() |
# | 214 | occupation           | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 215 | occupation           | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.21          | DecisionTreeRegressor() |
# | 216 | occupation           | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.21          | DecisionTreeRegressor() |
# | 217 | occupation           | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.16          | DecisionTreeRegressor() |
# | 218 | occupation           | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.22          | DecisionTreeRegressor() |
# | 219 | occupation           | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 220 | occupation           | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.07          | DecisionTreeRegressor() |
# | 221 | occupation           | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 222 | occupation           | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.36          | DecisionTreeRegressor() |
# | 223 | occupation           | outlier              | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 224 | relationship         | sex_ Female          | 0.22      | regression         | True             | mean absolute error | 0.34             | 0.27          | DecisionTreeRegressor() |
# | 225 | relationship         | sex_ Male            | 0.22      | regression         | True             | mean absolute error | 0.34             | 0.27          | DecisionTreeRegressor() |
# | 226 | relationship         | income_ <=50K        | 0         | regression         | True             | mean absolute error | 0.22             | 0.27          | DecisionTreeRegressor() |
# | 227 | relationship         | income_ >50K         | 0         | regression         | True             | mean absolute error | 0.22             | 0.27          | DecisionTreeRegressor() |
# | 228 | relationship         | workclass            | 0         | regression         | True             | mean absolute error | 0.73             | 0.84          | DecisionTreeRegressor() |
# | 229 | relationship         | education            | 0         | regression         | True             | mean absolute error | 2.68             | 2.86          | DecisionTreeRegressor() |
# | 230 | relationship         | marital_status       | 0.28      | regression         | True             | mean absolute error | 1.2              | 0.86          | DecisionTreeRegressor() |
# | 231 | relationship         | occupation           | 0         | regression         | True             | mean absolute error | 3.72             | 3.73          | DecisionTreeRegressor() |
# | 232 | relationship         | relationship         | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
# | 233 | relationship         | race                 | 0         | regression         | True             | mean absolute error | 0.35             | 0.57          | DecisionTreeRegressor() |
# | 234 | relationship         | native_country       | 0         | regression         | True             | mean absolute error | 2.2              | 3.9           | DecisionTreeRegressor() |
# | 235 | relationship         | age                  | 0.13      | regression         | True             | mean absolute error | 11.05            | 9.58          | DecisionTreeRegressor() |
# | 236 | relationship         | fnlwgt               | 0         | regression         | True             | mean absolute error | 75582.2          | 76200.1       | DecisionTreeRegressor() |
# | 237 | relationship         | education_num        | 0         | regression         | True             | mean absolute error | 1.81             | 1.85          | DecisionTreeRegressor() |
# | 238 | relationship         | capital_gain         | 0         | regression         | True             | mean absolute error | 416.05           | 757.23        | DecisionTreeRegressor() |
# | 239 | relationship         | capital_loss         | 0         | regression         | True             | mean absolute error | 41.37            | 80.47         | DecisionTreeRegressor() |
# | 240 | relationship         | hours_per_week       | 0         | regression         | True             | mean absolute error | 6.99             | 7.6           | DecisionTreeRegressor() |
# | 241 | relationship         | total_income         | 0         | regression         | True             | mean absolute error | 457.42           | 804.71        | DecisionTreeRegressor() |
# | 242 | relationship         | financial_dependency | 0         | target_is_constant | True             |                     | 1                | 1             |                         |
# | 243 | relationship         | income_ <=50K_log    | 0         | regression         | True             | mean absolute error | 0.15             | 0.19          | DecisionTreeRegressor() |
# | 244 | relationship         | income_ >50K_log     | 0         | regression         | True             | mean absolute error | 0.15             | 0.19          | DecisionTreeRegressor() |
# | 245 | relationship         | race_log             | 0         | regression         | True             | mean absolute error | 0.1              | 0.16          | DecisionTreeRegressor() |
# | 246 | relationship         | native_country_log   | 0         | regression         | True             | mean absolute error | 0.13             | 0.22          | DecisionTreeRegressor() |
# | 247 | relationship         | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 248 | relationship         | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.06          | DecisionTreeRegressor() |
# | 249 | relationship         | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# ...
# | 779 | outlier              | fnlwgt_log           | 0         | regression         | True             | mean absolute error | 0.46             | 0.47          | DecisionTreeRegressor() |
# | 780 | outlier              | capital_gain_log     | 0         | regression         | True             | mean absolute error | 0.58             | 1.08          | DecisionTreeRegressor() |
# | 781 | outlier              | capital_loss_log     | 0         | regression         | True             | mean absolute error | 0.18             | 0.35          | DecisionTreeRegressor() |
# | 782 | outlier              | total_income_log     | 0         | regression         | True             | mean absolute error | 0.76             | 1.38          | DecisionTreeRegressor() |
# | 783 | outlier              | outlier              | 1         | predict_itself     | True             |                     | 0                | 1             |                         |
#
# Correlation Matrix:
#
# |                      | sex_ Female   | sex_ Male   | income_ <=50K   | income_ >50K   | workclass   | education   | marital_status   | occupation   | relationship   | race   | native_country   | age   | fnlwgt   | education_num   | capital_gain   | capital_loss   | hours_per_week   | total_income   | financial_dependency   | income_ <=50K_log   | income_ >50K_log   | race_log   | native_country_log   | fnlwgt_log   | capital_gain_log   | capital_loss_log   | total_income_log   | outlier   |
# |:---------------------|:--------------|:------------|:----------------|:---------------|:------------|:------------|:-----------------|:-------------|:---------------|:-------|:-----------------|:------|:---------|:----------------|:---------------|:---------------|:-----------------|:---------------|:-----------------------|:--------------------|:-------------------|:-----------|:---------------------|:-------------|:-------------------|:-------------------|:-------------------|:----------|
# | sex_ Female          | 1             | -1          | 0.21            | -0.21          | -0.09       | 0.03        | 0.12             | -0.08        | 0.58           | -0.09  | 0.01             | -0.08 | -0.03    | -0              | -0.06          | -0.04          | -0.23            | -0.06          | nan                    | 0.21                | -0.21              | -0.08      | 0.01                 | -0.02        | -0.06              | -0.03              | -0.06              | nan       |
# | sex_ Male            | -1            | 1           | -0.21           | 0.21           | 0.09        | -0.03       | -0.12            | 0.08         | -0.58          | 0.09   | -0.01            | 0.08  | 0.03     | 0               | 0.06           | 0.04           | 0.23             | 0.06           | nan                    | -0.21               | 0.21               | 0.08       | -0.01                | 0.02         | 0.06               | 0.03               | 0.06               | nan       |
# | income_ <=50K        | 0.21          | -0.21       | 1               | -1             | -0.04       | -0.07       | 0.2              | -0.07        | 0.24           | -0.07  | -0.02            | -0.22 | 0.02     | -0.31           | -0.29          | -0.1           | -0.21            | -0.3           | nan                    | 1                   | -1                 | -0.06      | -0.01                | 0            | -0.23              | -0.09              | -0.25              | nan       |
# | income_ >50K         | -0.21         | 0.21        | -1              | 1              | 0.04        | 0.07        | -0.2             | 0.07         | -0.24          | 0.07   | 0.02             | 0.22  | -0.02    | 0.31            | 0.29           | 0.1            | 0.21             | 0.3            | nan                    | -1                  | 1                  | 0.06       | 0.01                 | -0           | 0.23               | 0.09               | 0.25               | nan       |
# | workclass            | -0.09         | 0.09        | -0.04           | 0.04           | 1           | 0.02        | -0.06            | 0.25         | -0.09          | 0.05   | -0               | 0     | -0.02    | 0.04            | 0.02           | -0             | 0.13             | 0.02           | nan                    | -0.04               | 0.04               | 0.04       | -0                   | -0.02        | 0.01               | -0                 | 0.01               | nan       |
# | education            | 0.03          | -0.03       | -0.07           | 0.07           | 0.02        | 1           | -0.04            | -0.02        | -0.01          | 0.01   | 0.06             | -0.01 | -0.03    | 0.35            | 0.02           | 0.03           | 0.05             | 0.02           | nan                    | -0.07               | 0.07               | 0.01       | 0.04                 | -0.03        | 0.02               | 0.03               | 0.03               | nan       |
# | marital_status       | 0.12          | -0.12       | 0.2             | -0.2           | -0.06       | -0.04       | 1                | -0.01        | 0.18           | -0.07  | -0.02            | -0.28 | 0.03     | -0.06           | -0.06          | -0.04          | -0.19            | -0.07          | nan                    | 0.2                 | -0.2               | -0.06      | -0.02                | 0.02         | -0.06              | -0.04              | -0.07              | nan       |
# | occupation           | -0.08         | 0.08        | -0.07           | 0.07           | 0.25        | -0.02       | -0.01            | 1            | -0.07          | 0.01   | -0.01            | -0.02 | -0       | 0.1             | 0.02           | 0.01           | 0.07             | 0.02           | nan                    | -0.07               | 0.07               | 0.01       | -0.01                | 0            | 0.01               | 0.01               | 0.02               | nan       |
# | relationship         | 0.58          | -0.58       | 0.24            | -0.24          | -0.09       | -0.01       | 0.18             | -0.07        | 1              | -0.12  | -0.01            | -0.26 | 0.01     | -0.09           | -0.08          | -0.05          | -0.25            | -0.08          | nan                    | 0.24                | -0.24              | -0.1       | 0                    | 0.01         | -0.07              | -0.04              | -0.08              | nan       |
# | race                 | -0.09         | 0.09        | -0.07           | 0.07           | 0.05        | 0.01        | -0.07            | 0.01         | -0.12          | 1      | 0.13             | 0.02  | -0.02    | 0.03            | 0.02           | 0.02           | 0.04             | 0.02           | nan                    | -0.07               | 0.07               | 0.98       | 0.11                 | -0.01        | 0.02               | 0.02               | 0.03               | nan       |
# | native_country       | 0.01          | -0.01       | -0.02           | 0.02           | -0          | 0.06        | -0.02            | -0.01        | -0.01          | 0.13   | 1                | 0     | -0.05    | 0.05            | 0.01           | 0.01           | 0                | 0.02           | nan                    | -0.02               | 0.02               | 0.13       | 0.94                 | -0.06        | 0.01               | 0.01               | 0.02               | nan       |
# | age                  | -0.08         | 0.08        | -0.22           | 0.22           | 0           | -0.01       | -0.28            | -0.02        | -0.26          | 0.02   | 0                | 1     | -0.08    | 0.03            | 0.08           | 0.01           | 0.08             | 0.08           | nan                    | -0.22               | 0.22               | 0.02       | -0                   | -0.06        | 0.08               | 0.01               | 0.07               | nan       |
# | fnlwgt               | -0.03         | 0.03        | 0.02            | -0.02          | -0.02       | -0.03       | 0.03             | -0           | 0.01           | -0.02  | -0.05            | -0.08 | 1        | -0.05           | -0.02          | -0.03          | -0.02            | -0.02          | nan                    | 0.02                | -0.02              | 0          | -0.03                | 0.91         | -0.02              | -0.03              | -0.03              | nan       |
# | education_num        | -0            | 0           | -0.31           | 0.31           | 0.04        | 0.35        | -0.06            | 0.1          | -0.09          | 0.03   | 0.05             | 0.03  | -0.05    | 1               | 0.12           | 0.05           | 0.14             | 0.12           | nan                    | -0.31               | 0.31               | 0.02       | 0.01                 | -0.04        | 0.09               | 0.05               | 0.1                | nan       |
# | capital_gain         | -0.06         | 0.06        | -0.29           | 0.29           | 0.02        | 0.02        | -0.06            | 0.02         | -0.08          | 0.02   | 0.01             | 0.08  | -0.02    | 0.12            | 1              | -0.03          | 0.07             | 0.99           | nan                    | -0.29               | 0.29               | 0.02       | 0.01                 | 0.01         | 0.88               | -0.03              | 0.78               | nan       |
# | capital_loss         | -0.04         | 0.04        | -0.1            | 0.1            | -0          | 0.03        | -0.04            | 0.01         | -0.05          | 0.02   | 0.01             | 0.01  | -0.03    | 0.05            | -0.03          | 1              | 0.02             | 0.11           | nan                    | -0.1                | 0.1                | 0.02       | 0                    | -0.01        | -0.04              | 0.99               | 0.42               | nan       |
# | hours_per_week       | -0.23         | 0.23        | -0.21           | 0.21           | 0.13        | 0.05        | -0.19            | 0.07         | -0.25          | 0.04   | 0                | 0.08  | -0.02    | 0.14            | 0.07           | 0.02           | 1                | 0.07           | nan                    | -0.21               | 0.21               | 0.04       | -0                   | -0.03        | 0.06               | 0.02               | 0.07               | nan       |
# | total_income         | -0.06         | 0.06        | -0.3            | 0.3            | 0.02        | 0.02        | -0.07            | 0.02         | -0.08          | 0.02   | 0.02             | 0.08  | -0.02    | 0.12            | 0.99           | 0.11           | 0.07             | 1              | nan                    | -0.3                | 0.3                | 0.02       | 0.01                 | 0            | 0.87               | 0.11               | 0.84               | nan       |
# | financial_dependency | nan           | nan         | nan             | nan            | nan         | nan         | nan              | nan          | nan            | nan    | nan              | nan   | nan      | nan             | nan            | nan            | nan              | nan            | nan                    | nan                 | nan                | nan        | nan                  | nan          | nan                | nan                | nan                | nan       |
# | income_ <=50K_log    | 0.21          | -0.21       | 1               | -1             | -0.04       | -0.07       | 0.2              | -0.07        | 0.24           | -0.07  | -0.02            | -0.22 | 0.02     | -0.31           | -0.29          | -0.1           | -0.21            | -0.3           | nan                    | 1                   | -1                 | -0.06      | -0.01                | 0            | -0.23              | -0.09              | -0.25              | nan       |
# | income_ >50K_log     | -0.21         | 0.21        | -1              | 1              | 0.04        | 0.07        | -0.2             | 0.07         | -0.24          | 0.07   | 0.02             | 0.22  | -0.02    | 0.31            | 0.29           | 0.1            | 0.21             | 0.3            | nan                    | -1                  | 1                  | 0.06       | 0.01                 | -0           | 0.23               | 0.09               | 0.25               | nan       |
# | race_log             | -0.08         | 0.08        | -0.06           | 0.06           | 0.04        | 0.01        | -0.06            | 0.01         | -0.1           | 0.98   | 0.13             | 0.02  | 0        | 0.02            | 0.02           | 0.02           | 0.04             | 0.02           | nan                    | -0.06               | 0.06               | 1          | 0.1                  | 0.02         | 0.02               | 0.02               | 0.02               | nan       |
# | native_country_log   | 0.01          | -0.01       | -0.01           | 0.01           | -0          | 0.04        | -0.02            | -0.01        | 0              | 0.11   | 0.94             | -0    | -0.03    | 0.01            | 0.01           | 0              | -0               | 0.01           | nan                    | -0.01               | 0.01               | 0.1        | 1                    | -0.04        | 0.01               | 0                  | 0.01               | nan       |
# | fnlwgt_log           | -0.02         | 0.02        | 0               | -0             | -0.02       | -0.03       | 0.02             | 0            | 0.01           | -0.01  | -0.06            | -0.06 | 0.91     | -0.04           | 0.01           | -0.01          | -0.03            | 0              | nan                    | 0                   | -0                 | 0.02       | -0.04                | 1            | -0                 | -0.01              | -0                 | nan       |
# | capital_gain_log     | -0.06         | 0.06        | -0.23           | 0.23           | 0.01        | 0.02        | -0.06            | 0.01         | -0.07          | 0.02   | 0.01             | 0.08  | -0.02    | 0.09            | 0.88           | -0.04          | 0.06             | 0.87           | nan                    | -0.23               | 0.23               | 0.02       | 0.01                 | -0           | 1                  | -0.04              | 0.89               | nan       |
# | capital_loss_log     | -0.03         | 0.03        | -0.09           | 0.09           | -0          | 0.03        | -0.04            | 0.01         | -0.04          | 0.02   | 0.01             | 0.01  | -0.03    | 0.05            | -0.03          | 0.99           | 0.02             | 0.11           | nan                    | -0.09               | 0.09               | 0.02       | 0                    | -0.01        | -0.04              | 1                  | 0.42               | nan       |
# | total_income_log     | -0.06         | 0.06        | -0.25           | 0.25           | 0.01        | 0.03        | -0.07            | 0.02         | -0.08          | 0.03   | 0.02             | 0.07  | -0.03    | 0.1             | 0.78           | 0.42           | 0.07             | 0.84           | nan                    | -0.25               | 0.25               | 0.02       | 0.01                 | -0           | 0.89               | 0.42               | 1                  | nan       |
# | outlier              | nan           | nan         | nan             | nan            | nan         | nan         | nan              | nan          | nan            | nan    | nan              | nan   | nan      | nan             | nan            | nan            | nan              | nan            | nan                    | nan                 | nan                | nan        | nan                  | nan          | nan                | nan                | nan                | nan       |

# %%
# Get correlations with the target variable
target_correlations = corr_matrix['income_ >50K'].sort_values(ascending=False)

# Print top 10 positive correlations
print("\nTop 10 Positive Correlations with Target:\n")
print(target_correlations[:11].to_markdown(numalign="left", stralign="left"))  # Include target itself

# Print top 10 negative correlations
print("\nTop 10 Negative Correlations with Target:\n")
print(target_correlations[-11:].to_markdown(numalign="left", stralign="left"))  # Include target itself
# Out:
# Top 10 Positive Correlations with Target:
#
# |                  | income_ >50K   |
# |:-----------------|:---------------|
# | income_ >50K_log | 1              |
# | income_ >50K     | 1              |
# | education_num    | 0.306751       |
# | total_income     | 0.298815       |
# | capital_gain     | 0.286913       |
# | total_income_log | 0.246479       |
# | capital_gain_log | 0.227525       |
# | age              | 0.221597       |
# | hours_per_week   | 0.213549       |
# | sex_ Male        | 0.20873        |
# | capital_loss     | 0.0964537      |
#
# Top 10 Negative Correlations with Target:
#
# |                      | income_ >50K   |
# |:---------------------|:---------------|
# | native_country       | 0.0206718      |
# | native_country_log   | 0.0110037      |
# | fnlwgt_log           | -0.00247703    |
# | fnlwgt               | -0.0158429     |
# | marital_status       | -0.195166      |
# | sex_ Female          | -0.20873       |
# | relationship         | -0.244893      |
# | income_ <=50K_log    | -1             |
# | income_ <=50K        | -1             |
# | financial_dependency | nan            |
# | outlier              | nan            |
